# %% [markdown]
# # Probablistic Optimization
# This notebook approaches similar problems as the previous notebook, using probability to estimate the profit for each given price. This is quick, computed optimization & hopes to lead to the closed form solution
#
# ## The Current Challenge
# The challenge I'm currently facing is a difficulty conceptualizing thresholds in a closed form, hence the need for a computerized solution atm.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import scipy
from tqdm import tqdm
import plotly.graph_objects as go
from scipy.interpolate import griddata
import math
import sys
from scipy.stats import norm
import pandas as pd

# %%
# Assumptions: costs is an ascending array, scaling_param is between 0 and 1
def calculate_intervals(prices_unsorted, costs_unsorted, tiers, scaling_param):
    
    sorted_indices = np.argsort(costs_unsorted)
    costs = np.array(costs_unsorted)[sorted_indices]
    prices = np.array(prices_unsorted)[sorted_indices]

    thresholds = []
    thresholds.append(-sys.float_info.max)
    
    for i in range(tiers):
            if i == 0:
                thresholds.append(prices[0]/costs[0])
                                  
            else:
                intersection = (prices[i]-prices[i-1])/(costs[0] * ((costs[i]/costs[0])**(scaling_param)-(costs[i-1]/costs[0])**(scaling_param)))
                j = 0
                while intersection < thresholds[i - j]:
                    j += 1
                    if i == j:
                        intersection = prices[i]/(costs[0]*(costs[i]/costs[0])**(scaling_param))
                        break;
                    else:
                        intersection = (prices[i]-prices[i-j-1])/(costs[0] * ((costs[i]/costs[0])**(scaling_param)-(costs[i-j-1]/costs[0])**(scaling_param)))
                    
                thresholds.append(intersection)
                
                
    for i in range(tiers):
        if (thresholds[tiers - i] < thresholds[tiers-i-1]):
            thresholds[tiers-i-1] = thresholds[tiers - i]
            
    intervals = []
    for i in range(tiers):
        intervals.append((thresholds[i],thresholds[i+1]))
    
    intervals.append((thresholds[len(thresholds)-1],sys.float_info.max))

    intervals_ordered = [None] * len(intervals)
    intervals_ordered[0] = intervals[0]
    for i, idx in enumerate(sorted_indices):
        intervals_ordered[idx+1] = intervals[i+1]

    return intervals_ordered

# %%
# Assumption: scaling_param is between 0 and 1
def tier_probabilities(prices, costs, tiers, intervals, mu, sigma, pdf_type = 'uniform'):
    probabilities = []
    if (pdf_type == 'uniform'):
        start = mu - sigma
        end = mu + sigma
        point_prob = 1/(end - start)
        for i in range(tiers+1):
            probabilities.append(max((min(intervals[i][1],end)-max(intervals[i][0],start))*point_prob,0))
    elif (pdf_type == 'gaussian'):
        for i in range(tiers+1):
            probabilities.append(norm.cdf(intervals[i][1],mu,sigma) - norm.cdf(intervals[i][0],mu,sigma))
    else:
        raise ValueError('pdf_type must be uniform or gaussian')
    
    return probabilities

# %%
# calculate expected profit @ 1 customer based on probability distribution
def profit(prices, costs, tiers, scaling_param, mu, sigma, pdf_type = 'uniform'):
    intervals = calculate_intervals(prices,costs,tiers,scaling_param)
    probabilities = tier_probabilities(prices, costs, tiers, intervals, mu, sigma, pdf_type)
    
    profits = [pr * (p - c) for (p, c, pr) in zip(prices, costs, probabilities[1:])]

    return sum(profits)

# %%
# negative of profit because scipy likes to minimize
def objective(prices, costs, tiers, scaling_param, mu, sigma, pdf_type = 'uniform'):
    return -profit(prices, costs, tiers, scaling_param, mu, sigma, pdf_type)

# %%
## Test run of optimization

# %%
C = [1,3,5]
B = len(C);
scaling_lambda = 4/5
mu = 2
sigma = 0.5

bounds = [(1,5),(3,15),(5,20)]

result = scipy.optimize.dual_annealing(objective, bounds, args=(C, B, scaling_lambda, mu, sigma, 'uniform'))
print(result)
# Out:
#      fun: -1.1950442758332946
#  message: ['Maximum number of iteration reached']
#     nfev: 6073
#     nhev: 0
#      nit: 1000
#     njev: 18
#   status: 0
#  success: True
#        x: array([1.75000023, 4.51028152, 7.02987358])

# %% [markdown]
# # Visualizations + Simulations of Optimization
#
# ## Two Tiers

# %%
# PARAMS
scaling_lambda = 2/3
mu = 3
sigma = 1
B = 2

c_1_list = []
c_2_list = []
p_1_list = []
p_2_list = []
profit_list = []

# TEST PTS
C_1 = np.linspace(1,10,20)
C_2 = np.linspace(1,10,20)
for c_1 in tqdm(C_1):
    for c_2 in C_2:
        C = [c_1, c_2]
        args = (C,B,scaling_lambda,mu,sigma,'uniform')
        bounds = [(c_1, c_1 * 5), (c_2, c_2 * 5)]
        result = scipy.optimize.dual_annealing(objective, bounds, args=args)
        c_1_list.append(c_1)
        c_2_list.append(c_2)
        p_1_list.append(result.x[0])
        p_2_list.append(result.x[1])
        profit_list.append(result.fun * -1)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/tmp/ipykernel_149/4256592931.py:16: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# 100%|██████████| 20/20 [02:52<00:00,  8.60s/it]

# %%
# make vis for 2 tier plots
def make_vis(X, Y, Z, xlabel, ylabel, zlabel, title, azim=225):
    fig = plt.figure(figsize=(12, 8)) 
    ax = fig.add_subplot(111, projection='3d') 

    surface = ax.plot_surface(
        X, Y, Z, cmap='plasma', alpha=0.9
    )

    cbar = fig.colorbar(surface, shrink=0.5, aspect=10)
    cbar.set_label(zlabel)


    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_zlabel(zlabel)
    ax.set_title(title)

    ax.view_init(elev=25, azim=azim)

    # Set background color for axes
    ax.w_xaxis.set_pane_color((0.9, 0.9, 0.9, 1.0))  # Light gray
    ax.w_yaxis.set_pane_color((0.9, 0.9, 0.9, 1.0))
    ax.w_zaxis.set_pane_color((0.9, 0.9, 0.9, 1.0))

    # Show gridlines
    ax.grid(True)

    plt.show()

# %%
# fig = plt.figure(figsize=(12, 16))
# ax = Axes3D(fig)

X,Y = np.meshgrid(C_1, C_2)
Z = np.array(p_1_list).reshape(X.shape).T


make_vis(X,Y,Z,"Tier 1 Cost", "Tier 2 Cost", "Optimal Tier 1 Price", "Optimal Tier 1 Price as a Function of Costs")

# %%
# fig = plt.figure(figsize=(12, 16))
# ax = Axes3D(fig)

X,Y = np.meshgrid(C_1, C_2)
Z = np.array(p_2_list).reshape(X.shape).T


make_vis(X,Y,Z,"Tier 1 Cost", "Tier 2 Cost", "Optimal Tier 2 Price", "Optimal Tier 2 Price as a Function of Costs")

# %%
# fig = plt.figure(figsize=(12, 16))
# ax = Axes3D(fig)

X,Y = np.meshgrid(C_1, C_2)
Z = np.array(profit_list).reshape(X.shape).T


make_vis(X,Y,Z,"Tier 1 Cost", "Tier 2 Cost", "Optimal Profit", "Optimal Profit as a Function of Costs", azim=200)

# %%
mu = 2
sigma = 0.5
C = [1,4]
scaling_lambda = 5/6

# %%
# generate sample points
lowers = [cost *(mu - 2 * sigma) for cost in C] 
uppers = [cost * (mu + 2 * sigma) for cost in C]


tier_1_prices = np.linspace(lowers[0], uppers[0], num=100)
tier_2_prices = np.linspace(lowers[1], uppers[1], num=100)

prices_profits = []
profits = []

# compute profit at sample points
for t1_price in tqdm(tier_1_prices):
    for t2_price in tier_2_prices:
        P = [t1_price, t2_price]
        profit_point = profit(P, C, B, scaling_lambda, mu, sigma, 'uniform')
        profits.append(profit_point)
        prices_profits.append([t1_price, t2_price, profit_point])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 227.27it/s]

# %%
# fig = plt.figure(figsize=(12, 16))
# ax = Axes3D(fig)


prices_prof_arr = np.array(prices_profits)

tier_1_vals = prices_prof_arr[:,0]
tier_2_vals = prices_prof_arr[:,1]
profit_vals = prices_prof_arr[:,2]

X,Y = np.meshgrid(tier_1_prices, tier_2_prices)
Z = profit_vals.reshape(X.shape).T


make_vis(X,Y,Z,"Tier 1 Price", "Tier 2 Price", "Profit", f"Profit as a Function of Prices for Costs {C}")

# %%
# PARAMS
scaling_lambda = 4/5
mu = 2
sigma = 0.5
B = 3

c_1_list = []
c_2_list = []
c_3_list = []
p_1_list = []
p_2_list = []
p_3_list = []
profit_list = []

# TEST PTS
C_1 = np.linspace(1,10,10)
C_2 = np.linspace(1,10,10)
C_3 = np.linspace(1,10,10)


for c_1 in tqdm(C_1):
    for c_2 in C_2:
        for c_3 in C_3:
            C = [c_1, c_2, c_3]
            args = (C,B,scaling_lambda,mu,sigma,'uniform')
            bounds = [(c_1, c_1 * 3), (c_2, c_2 * 3), (c_3, c_3 * 3)]
            result = scipy.optimize.dual_annealing(objective, bounds, args=args)
            c_1_list.append(c_1)
            c_2_list.append(c_2)
            c_3_list.append(c_3)
            p_1_list.append(result.x[0])
            p_2_list.append(result.x[1])
            p_3_list.append(result.x[2])
            profit_list.append(result.fun * -1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/tmp/ipykernel_149/4256592931.py:16: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# /tmp/ipykernel_149/4256592931.py:24: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# 100%|██████████| 10/10 [10:58<00:00, 65.89s/it]

# %%
# Make vis for 3 tier plot
def make_vis_3d(x, y, z, dependent, xlabel, ylabel, zlabel, deplabel, title):
    fig = plt.figure(figsize=(12, 16))
    ax = fig.add_subplot(111, projection='3d')

    scat = ax.scatter(x, y, z, c = dependent, cmap = plt.cm.viridis, s = 10)
    cbar = fig.colorbar(scat)
    cbar.set_label(deplabel)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_zlabel(zlabel)
    ax.set_title(title)
    
    ax.view_init(elev=35, azim=215)



    plt.show()

# %%
make_vis_3d(c_1_list, c_2_list, c_3_list, p_1_list, "Cost of Tier 1", "Cost of Tier 2", "Cost of Tier 3", "Optimal Tier 1 Price", "Optimal Price of Tier 1 as Function of Costs")

# %%
make_vis_3d(c_1_list, c_2_list, c_3_list, p_1_list, "Cost of Tier 1", "Cost of Tier 2", "Cost of Tier 3", "Optimal Tier 2 Price", "Optimal Price of Tier 2 as Function of Costs")

# %%
make_vis_3d(c_1_list, c_2_list, c_3_list, p_1_list, "Cost of Tier 1", "Cost of Tier 2", "Cost of Tier 3", "Optimal Tier 3 Price", "Optimal Price of Tier 3 as Function of Costs")

# %% [markdown]
# # Over Time Based Approach
#
# This first trial is a failure. It uses coordinate descent, which fails to take into account the customers' decision makings. Prices need to be increased in conjunction with each other, which likely means gradient descent is necessary

# %%
def optimize_profit_naive(C, B, scaling_lambda, mu, sigma, pdf_type = 'uniform'):
    profit_time_series = [] # Time series of profit to be updated after each evaluation of objective function
    
    # When we are choosing p_0, we can see that valuation parameters generally take the range of (1, infinity)
    # Simple rule set. If profit is 0, we need to reduce profits. If profit is negative, we need to increase prices.
    P = C.copy()
    current_deltas = C.copy()
    
    profit_time_series.append((P.copy(), profit(P, C, B, scaling_lambda, mu, sigma, pdf_type)))
    lr = 1
    max_profit = profit_time_series[0][1]
    staticCounter  = 0
    
    while lr > 0:
        for i in range(B):
            P[i] += current_deltas[i]
            profit_new = profit(P,C,B,scaling_lambda,mu,sigma,pdf_type)
            profit_time_series.append((P.copy(),profit_new))
            if not profit_new > max_profit:
                P[i] -= current_deltas[i]
                current_deltas[i] = -lr * current_deltas[i]
            else:
                current_deltas[i] = lr * current_deltas[i]
        lr -= 0.01
        max_profit = max(prof[1] for prof in profit_time_series)
        
        if(staticCounter == 2 * len(P)):
            break
        
    return profit_time_series

# %%
C = [1,3,5]
B = len(C);
scaling_lambda = 4/5
mu = 2
sigma = 0.5

optimize_profit_naive(C, B, scaling_lambda, mu, sigma)
# Out:
# [([1, 3, 5], 0.0),
#  ([2, 3, 5], 0.0),
#  ([1, 6, 5], 0.0),
#  ([1, 3, 10], 0.0),
#  ([0, 3, 5], -0.4055616465621483),
#  ([1, 0, 5], -3.0),
#  ([1, 3, 0], -5.0),
#  ([1.99, 3, 5], 0.0),
#  ([1.0, 5.97, 5], 0.0),
#  ([1.0, 3.0, 9.95], 0.0),
#  ([0.02980000000000005, 3.0, 4.999999999999999], -0.3824572050740089),
#  ([1.0, 0.08940000000000037, 4.999999999999999], -2.9105999999999996),
#  ([1.0, 3.0, 0.14899999999999913], -4.851000000000001),
#  ([1.9410939999999999, 3.0, 4.999999999999999], -7.592340997412033e-16),
#  ([1.0, 5.823281999999999, 4.999999999999999], -8.664630637425235e-16),
#  ([1.0, 2.9999999999999996, 9.705469999999998], -4.440892098500626e-16),
#  ([0.09654976000000015, 2.9999999999999996, 4.999999999999998],
#   -0.3331611373063628),
#  ([1.0, 0.28964928000000034, 4.999999999999998], -2.7103507199999997),
#  ([1.0, 2.9999999999999996, 0.48274879999999865], -4.517251200000001),
#  ([1.8582777279999998, 2.9999999999999996, 4.999999999999998],
#   -1.5829403594618679e-15),
#  ([1.0, 5.574833183999999, 4.999999999999998], -1.7329261274850474e-15),
#  ([1.0, 3.0, 9.291388639999997], 0.0),
